# %%
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_csv('../creditcard.csv', sep=',')

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df['Class'].value_counts().plot(kind='bar', style='Fivethirtyeight')
# Out:
# <AxesSubplot:>

# %%
df['Class'].value_counts().plot(kind='bar', style='Fivethirtyeight')
plt.yscale(value='log')

# %%
class_0 = df.loc[df['Class'] == 0, ['V1']]
class_1 = df.loc[df['Class'] == 1, ['V1']]
class_1
# Out:
#               V1
# 541    -2.312227
# 623    -3.043541
# 4920   -2.303350
# 6108   -4.397974
# 6329    1.234235
# ...          ...
# 279863 -1.927883
# 280143  1.378559
# 280149 -0.676143
# 281144 -3.113832
# 281674  1.991976
#
# [492 rows x 1 columns]

# %%
plt.hist(class_0['V1'], bins=20, density=True, alpha=0.5, label='Class 0', color='grey')
plt.hist(class_1['V1'], bins=20, density=True, alpha=0.5, label='Class 1', color='red')
plt.legend()
plt.title('График f(x)')
plt.show()
